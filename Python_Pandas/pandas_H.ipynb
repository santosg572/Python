# %%
# pandas -ejemplos

import pandas as pd
import numpy as np

nsuj = 20
nmuj = 12
nhom = 8

edad = np.round(np.random.uniform(55,70,nsuj))
#--------------------------- Datos de nombres

nombres_H = []
sexo_H = []
peso_H = np.round(np.random.normal(60,7,nhom))

for i in range(nhom):
    nombres_H.append('Juan'+str(i))
    sexo_H.append('H')

#----------------------------- datos mujeres
nombres_M = []
sexo_M = []
peso_M = np.round(np.random.normal(55,7,nmuj))

for i in range(nm):
    nombres_M.append('Lupita'+str(i))
    sexo_M.append('M')

nombres_M.extend(nombres_H)
sexo_M.extend(sexo_H)

PESO = np.concatenate((peso_M, peso_H))

datos = {'nombres' : nombres_M, 'SEXO': sexo_M, 'PESO' : PESO}

tabla = pd.DataFrame(datos)

print(tabla.shape)
#------------------------------------------------------

print(tabla.info())

#------------------------------------------------------

sueldo = np.round(np.random.uniform(5000,10000,nsuj))
tabla.insert(1, 'SUELDO', sueldo)
print(tabla)
#------------------------------------------------------
dd = tabla['SUELDO']
print(dd)
#------------------------------------------------------
dd1 = tabla.loc[[5,7],['SUELDO','nombres']]
print(dd1)
#------------------------------------------------------

dd1 = tabla.mean((1))
#print(dd1)
#------------------------------------------------------

#------------------------------------------------------

#------------------------------------------------------

#------------------------------------------------------
# Out:
# (20, 3)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   nombres  20 non-null     object
#  1   SEXO     20 non-null     object
#  2   PESO     20 non-null     float64
# dtypes: float64(1), object(2)
# memory usage: 608.0+ bytes
# None
#      nombres  SUELDO SEXO  PESO
# 0    Lupita0  8388.0    M  54.0
# 1    Lupita1  5083.0    M  66.0
# 2    Lupita2  9541.0    M  56.0
# 3    Lupita3  8310.0    M  37.0
# 4    Lupita4  7750.0    M  47.0
# 5    Lupita5  9030.0    M  65.0
# 6    Lupita6  5744.0    M  57.0
# 7    Lupita7  6942.0    M  53.0
# 8    Lupita8  7348.0    M  45.0
# 9    Lupita9  9563.0    M  62.0
# 10  Lupita10  5526.0    M  59.0
# 11  Lupita11  7545.0    M  64.0
# 12     Juan0  6387.0    H  59.0
# 13     Juan1  8606.0    H  70.0
# 14     Juan2  7261.0    H  61.0
# 15     Juan3  6515.0    H  78.0
# 16     Juan4  6211.0    H  68.0
# 17     Juan5  9362.0    H  65.0
# 18     Juan6  6534.0    H  64.0
# 19     Juan7  5617.0    H  67.0
# 0     8388.0
# 1     5083.0
# 2     9541.0
# 3     8310.0
# 4     7750.0
# 5     9030.0
# 6     5744.0
# 7     6942.0
# 8     7348.0
# 9     9563.0
# 10    5526.0
# 11    7545.0
# 12    6387.0
# 13    8606.0
# 14    7261.0
# 15    6515.0
# 16    6211.0
# 17    9362.0
# 18    6534.0
# 19    5617.0
# Name: SUELDO, dtype: float64
#    SUELDO  nombres
# 5  9030.0  Lupita5
# 7  6942.0  Lupita7
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 57
#      54 print(dd1)
#      55 #------------------------------------------------------
# ---> 57 dd1 = tabla.mean(1)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:11720, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11712 @doc(make_doc("mean", ndim=2))
#   11713 def mean(
#   11714     self,
#    (...)
#   11718     **kwargs,
#   11719 ):
# > 11720     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11721     if isinstance(result, Series):
#   11722         result = result.__finalize__(self, method="mean")
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)
#   12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:11589, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11585     df = df.T
#   11587 # After possibly _get_data and transposing, we are now in the
#   11588 #  simple case where we can use BlockManager.reduce
# > 11589 res = df._mgr.reduce(blk_func)
#   11590 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11591 if out_dtype is not None and out.dtype != "boolean":
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py:1519, in BlockManager.reduce(self, func)
#    1517 res_blocks: list[Block] = []
#    1518 for blk in self.blocks:
# -> 1519     nbs = blk.reduce(func)
#    1520     res_blocks.extend(nbs)
#    1522 index = Index([None])  # placeholder
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/internals/blocks.py:406, in Block.reduce(self, func)
#     400 @final
#     401 def reduce(self, func) -> list[Block]:
#     402     # We will apply the function and reshape the result into a single-row
#     403     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     404     assert self.ndim == 2
# --> 406     result = func(self.values)
#     408     if self.values.ndim == 1:
#     409         res_values = result
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py:11508, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11506         return np.array([result])
#   11507 else:
# > 11508     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File ~/miniconda3/lib/python3.9/site-packages/pandas/core/nanops.py:719, in nanmean(values, axis, skipna, mask)
#     716     dtype_count = dtype
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
# --> 719 the_sum = values.sum(axis, dtype=dtype_sum)
#     720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~/miniconda3/lib/python3.9/site-packages/numpy/core/_methods.py:49, in _sum(a, axis, dtype, out, keepdims, initial, where)
#      47 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#      48          initial=_NoValue, where=True):
# ---> 49     return umr_sum(a, axis, dtype, out, keepdims, initial, where)
#
# TypeError: can only concatenate str (not "float") to str

# %%
mujeres_nombres.extend(hombres_nombres)
